# %%
import pandas as pd

# %%
nutrition = pd.read_csv('chubbygrub.csv')

# %%
nutrition.head(10)
# Out:
#                   name  calories  carbs  fat       restaurant category
# 0  A&W® Diet Root Beer         0    0.0    0  A&W Restaurants   Drinks
# 1  A&W® Diet Root Beer         0    0.0    0  A&W Restaurants   Drinks
# 2  A&W® Diet Root Beer         0    0.0    0  A&W Restaurants   Drinks
# 3  A&W® Diet Root Beer         0    0.0    0  A&W Restaurants   Drinks
# 4  A&W® Diet Root Beer         0    0.0    0  A&W Restaurants   Drinks
# 5  A&W® Diet Root Beer         0    0.0    0  A&W Restaurants   Drinks
# 6       A&W® Root Beer       160   43.0    0  A&W Restaurants   Drinks
# 7       A&W® Root Beer       220   58.0    0  A&W Restaurants   Drinks
# 8       A&W® Root Beer       270   72.0    0  A&W Restaurants   Drinks
# 9       A&W® Root Beer       440  116.0    0  A&W Restaurants   Drinks

# %%
nutrition.tail()
# Out:
#                       name  calories  carbs  fat    restaurant  \
# 4971         Chive & Onion       130    4.0   11  Panera Bread
# 4972                 Plain       100    1.0   10  Panera Bread
# 4973                 Plain       180    2.0   18  Panera Bread
# 4974  Reduced Fat Hazelnut        80    3.0    6  Panera Bread
# 4975  Reduced Fat Hazelnut       140    6.0   11  Panera Bread
#
#                   category
# 4971  Cream Cheese Spreads
# 4972  Cream Cheese Spreads
# 4973  Cream Cheese Spreads
# 4974  Cream Cheese Spreads
# 4975  Cream Cheese Spreads

# %%
nutrition.shape[0]
# Out:
# 4976

# %%
id(nutrition)
# Out:
# 4521889744

# %%
nutrition.describe()
# Out:
#           calories        carbs          fat
# count  4976.000000  4859.000000  4976.000000
# mean    490.679059    47.799959    24.602492
# std     391.185556    45.030591    27.557719
# min       0.000000     0.000000     0.000000
# 25%     220.000000    19.000000     7.000000
# 50%     400.000000    40.000000    18.000000
# 75%     670.000000    65.000000    34.000000
# max    8820.000000   881.000000   540.000000

# %%
nutrition.sort_values(['restaurant', 'calories'])
# Out:
#                                       name  calories  carbs  fat  \
# 0                      A&W® Diet Root Beer         0    0.0    0
# 1                      A&W® Diet Root Beer         0    0.0    0
# 2                      A&W® Diet Root Beer         0    0.0    0
# 3                      A&W® Diet Root Beer         0    0.0    0
# 4                      A&W® Diet Root Beer         0    0.0    0
# 5                      A&W® Diet Root Beer         0    0.0    0
# 32                                 Limeade       140   38.0    0
# 6                           A&W® Root Beer       160   43.0    0
# 251     A&W® Diet Root Beer Float (medium)       170   30.0    5
# 252      A&W® Diet Root Beer Float (small)       170   30.0    5
# 428                     Extra Burger Patty       170    2.0   12
# 427        Corn Dog Nuggets® (Small/ Kids)       180   20.0    8
# 16                          Cherry Limeade       190   51.0    0
# ...

# %%
kids_meals = nutrition['category'] == "Kid's Meals"
nutrition[kids_meals].sort_values('calories', ascending=False)
# Out:
#                                                    name  calories  carbs  fat  \
# 3836                                    Captain’s Catch      1060   78.0   70
# 3660                        Kids OREO® Cookie Milkshake       780   97.0   41
# 3954                                     Kid Beef Minis       779   58.0   46
# 3845                                 Mini Beach Burgers       760   68.0   41
# 3656                        Kids Mini Cheeseburgers – 2       740   47.0   46
# 3683                           Mac ‘N Cheese Kids’ Meal       735   86.0   35
# 3682                             Chicken Leg Kids’ meal       730   62.0   43
# 3760                        Kids’ OREO® Blender Blaster       690   88.0   33
# 3940                               Red’s Pizzeria Pizza       690   58.0   35
# 3960                                  Kid Mac ‘n Cheese       680   61.0   37
# 3681                        2 Piece Supremes Kids’ Meal       680   69.0   34
# ...

# %%
nutrition[nutrition['calories'] > 2000]
# Out:
#                                                    name  calories  carbs  fat  \
# 1371              12 piece & 6 biscuit box (serves 5-7)      5300  327.0  324
# 1372                 12 piece Supremes box (serves 3-5)      2230  228.0   92
# 1379             20 piece & 10 biscuit box serves 9-11)      8820  545.0  540
# 1384               8 piece & 4 biscuit box (serves 3-5)      3534  218.0  216
# 1390                                   Ribs & More Ribs      2380   88.0  158
# 1995               Big Mouth® Bites w/ Ranch with fries      2120  163.0  133
# 1997     Jalapeno Smokehouse Burger w/ Ranch with fries      2210  136.0  144
# 2001  Southern Smokehouse Burger w/ Ancho Chile BBQ ...      2290  163.0  139
# 2375                                 East Coast Platter      2110  143.0  144
# 2402                                    The Big Hook Up      2750  220.0  168
# 2434                                  Appetizer Sampler      2375  169.0  162
# ...

# %%
# %matplotlib inline

# %%
nutrition['calories'].hist(bins=50)

# %%
nutrition['carbs'].hist(bins=50)

# %%
nutrition.plot('carbs', 'calories', kind='scatter')

# %%
nutrition.boxplot('calories')

# %%
nutrition.describe()
# Out:
#           calories        carbs          fat
# count  4976.000000  4859.000000  4976.000000
# mean    490.679059    47.799959    24.602492
# std     391.185556    45.030591    27.557719
# min       0.000000     0.000000     0.000000
# 25%     220.000000    19.000000     7.000000
# 50%     400.000000    40.000000    18.000000
# 75%     670.000000    65.000000    34.000000
# max    8820.000000   881.000000   540.000000

# %%
stock = pd.read_csv('LUV.csv')

# %%
stock['Close'].plot()

# %%
stock.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean    55.580000   56.160675   55.032262   55.602738   55.430730
# std      3.654674    3.644089    3.647469    3.639050    3.668339
# min     47.369999   47.900002   47.040001   47.070000   46.682053
# 25%     53.237500   53.747501   52.564998   53.070000   52.861612
# 50%     55.135000   55.539999   54.550001   55.170000   55.115000
# 75%     58.462499   58.877501   57.825000   58.457499   58.395001
# max     63.400002   64.389999   63.400002   64.239998   64.090019
#
#              Volume
# count  2.520000e+02
# mean   5.208359e+06
# std    2.265214e+06
# min    1.374000e+06
# 25%    3.744350e+06
# 50%    4.836150e+06
# 75%    5.921550e+06
# max    1.595260e+07

# %%
stock.tail()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 247  2017-11-27  55.139999  55.230000  54.490002  54.599998  54.599998
# 248  2017-11-28  54.660000  56.220001  54.509998  56.169998  56.169998
# 249  2017-11-29  56.549999  59.650002  56.509998  58.880001  58.880001
# 250  2017-11-30  58.910000  61.509998  58.900002  60.669998  60.669998
# 251  2017-12-01  60.509998  61.639999  59.509998  59.919998  59.919998
#
#        Volume
# 247   3129100
# 248   6663900
# 249   9702600
# 250  13382200
# 251   6184900

# %%
stock
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2016-12-02  47.369999  48.240002  47.299999  47.910000  47.515129
# 1    2016-12-05  48.080002  48.459999  47.040001  47.070000  46.682053
# 2    2016-12-06  47.389999  47.900002  47.160000  47.680000  47.387699
# 3    2016-12-07  47.709999  49.880001  47.400002  49.849998  49.544395
# 4    2016-12-08  49.980000  49.980000  49.240002  49.599998  49.295929
# 5    2016-12-09  49.889999  50.680000  49.220001  49.790001  49.484768
# 6    2016-12-12  49.360001  49.689999  48.919998  49.369999  49.067341
# 7    2016-12-13  49.470001  50.430000  49.450001  49.549999  49.246235
# 8    2016-12-14  49.500000  50.000000  48.900002  49.279999  48.977894
# 9    2016-12-15  49.430000  51.310001  49.400002  50.590000  50.279861
# 10   2016-12-16  50.740002  51.130001  49.889999  49.930000  49.623909
# 11   2016-12-19  50.259998  50.529999  49.720001  50.349998  50.041332
# ...

# %%
nutrition.to_csv('adsf.csv')

# %%
sql = """
SELECT * FROM RESTAURANTS
"""
